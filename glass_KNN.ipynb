# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
glass=pd.read_csv("A:/Data Science/assignments/KNN/glass.csv")

# %%
glass.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
glass.shape
# Out:
# (214, 10)

# %%
x=glass.iloc[:,0:9]
y=glass.iloc[:,9]

# %%
scaler=StandardScaler()
scaled_data=scaler.fit_transform(x_train)

# %%
from sklearn.neighbors import KNeighborsClassifier as KNC

# %%
acc=[]
count=[]
for i in range(3,50,2):
    neigh=KNC(n_neighbors=i)
    neigh.fit(x_train,y_train)
    predict=neigh.predict(x_test)
    score=np.mean(predict==y_test)
    acc.append(score)
    count.append(i)
    accuracy_rate=pd.DataFrame({'count':count,'accuracy':acc})

# %%
accuracy_rate
# Out:
#     count  accuracy
# 0       3  0.534884
# 1       5  0.534884
# 2       7  0.534884
# 3       9  0.488372
# 4      11  0.488372
# 5      13  0.488372
# 6      15  0.511628
# 7      17  0.558140
# 8      19  0.558140
# 9      21  0.534884
# 10     23  0.558140
# 11     25  0.534884
# 12     27  0.511628
# 13     29  0.534884
# 14     31  0.511628
# 15     33  0.488372
# 16     35  0.511628
# 17     37  0.511628
# 18     39  0.465116
# 19     41  0.465116
# 20     43  0.441860
# 21     45  0.418605
# 22     47  0.465116
# 23     49  0.465116

# %%
plt.figure(figsize=(15,5))
plt.plot(range(3,50,2),acc,linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)

# %%
#Selecting 10 as neighbour count
count=KNC(n_neighbors=20)
count.fit(x_train,y_train)
pred=count.predict(x_test)
score=np.mean(pred==y_test)

# %%
score
# Out:
# 0.5581395348837209

# %%
#Selecting neighbour count as 20 with accuracy 55%
